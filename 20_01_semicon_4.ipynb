# %% [markdown]
# <a href="https://colab.research.google.com/github/sysiphe0/dacon/blob/master/20_01_semicon_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import io

import keras
from keras.models import Sequential
from keras.layers import Dense

from sklearn.preprocessing import StandardScaler
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
train = pd.read_csv('/content/drive/My Drive/train.csv')

# %%
test = pd.read_csv('/content/drive/My Drive/test.csv')

# %%
train.head()
# Out:
#    layer_1  layer_2  layer_3  layer_4  ...       222       223       224       225
# 0       10       10       10       10  ...  0.419225  0.443250  0.433414  0.465502
# 1       10       10       10       20  ...  0.637706  0.625981  0.653231  0.637853
# 2       10       10       10       30  ...  0.747743  0.746037  0.737356  0.750391
# 3       10       10       10       40  ...  0.774712  0.801526  0.805305  0.784057
# 4       10       10       10       50  ...  0.787763  0.794948  0.819105  0.801781
#
# [5 rows x 230 columns]

# %%
train.describe()
# Out:
#              layer_1        layer_2  ...            224            225
# count  810000.000000  810000.000000  ...  810000.000000  810000.000000
# mean      155.000000     155.000000  ...       0.631166       0.633594
# std        86.554468      86.554468  ...       0.194146       0.193725
# min        10.000000      10.000000  ...      -0.005519      -0.006074
# 25%        80.000000      80.000000  ...       0.509036       0.512067
# 50%       155.000000     155.000000  ...       0.676692       0.679339
# 75%       230.000000     230.000000  ...       0.785774       0.787759
# max       300.000000     300.000000  ...       0.942411       0.943648
#
# [8 rows x 230 columns]

# %%
#@title 기본 제목 텍스트
#독립변수와 종속변수를 분리합니다.
from sklearn.model_selection import train_test_split
x_train = train.iloc[:,4:]  #Train 데이터의 독립변수
y_train = train.iloc[:,0:4] #Train 데이터의 종속변수
#x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size=0.2, random_state=0)
x_test = test.iloc[:,1:]    #Test  데이터의 독립변수

# %%
scaler = StandardScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
model = Sequential()
model.add(Dense(units=256, activation='relu', input_dim=226))
model.add(Dense(units=256, activation='relu'))
model.add(Dense(units=256, activation='relu'))
model.add(Dense(units=256, activation='relu'))
model.add(Dense(units=256, activation='relu'))
model.add(Dense(units=256, activation='relu'))
model.add(Dense(units=4, activation='linear'))
#모델을 컴파일합니다.
model.compile(loss='mae', optimizer='adam', metrics=['mae'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#모델을 학습합니다. 여기!!!!!!!!!!!
hist = model.fit(x_train, y_train, epochs=18, batch_size=20, validation_split = 0.05)

#예측값을 생성합니다.
pred_test = model.predict(x_test)
#submission 파일을 생성합니다.
sample_sub = pd.read_csv('/content/drive/My Drive/sample_submission.csv', index_col=0)
pred_test_new = np.rint(pred_test/10)*10
submission = sample_sub+pred_test_new
submission.to_csv('submission_200202_3.csv')
# Out:
# Train on 769500 samples, validate on 40500 samples
# Epoch 1/18
# 769500/769500 [==============================] - 172s 223us/step - loss: 12.1503 - mean_absolute_error: 12.1503 - val_loss: 26.2993 - val_mean_absolute_error: 26.2993
# Epoch 2/18
# 769500/769500 [==============================] - 172s 223us/step - loss: 10.9086 - mean_absolute_error: 10.9086 - val_loss: 25.3242 - val_mean_absolute_error: 25.3242
# Epoch 3/18
# 769500/769500 [==============================] - 170s 221us/step - loss: 10.1688 - mean_absolute_error: 10.1688 - val_loss: 22.2849 - val_mean_absolute_error: 22.2849
# Epoch 4/18
# 769500/769500 [==============================] - 168s 219us/step - loss: 9.6910 - mean_absolute_error: 9.6910 - val_loss: 25.6605 - val_mean_absolute_error: 25.6605
# Epoch 5/18
# 769500/769500 [==============================] - 167s 217us/step - loss: 9.3484 - mean_absolute_error: 9.3484 - val_loss: 22.5783 - val_mean_absolute_error: 22.5783
# Epoch 6/18
# 769500/769500 [==============================] - 165s 214us/step - loss: 9.0599 - mean_absolute_error: 9.0599 - val_loss: 19.6156 - val_mean_absolute_error: 19.6156
# Epoch 7/18
# 769500/769500 [==============================] - 164s 213us/step - loss: 8.7883 - mean_absolute_error: 8.7883 - val_loss: 23.2609 - val_mean_absolute_error: 23.2609
# Epoch 8/18
# 769500/769500 [==============================] - 163s 212us/step - loss: 8.6385 - mean_absolute_error: 8.6385 - val_loss: 19.7888 - val_mean_absolute_error: 19.7888
# Epoch 9/18
# 769500/769500 [==============================] - 163s 212us/step - loss: 8.4954 - mean_absolute_error: 8.4954 - val_loss: 23.5678 - val_mean_absolute_error: 23.5678
# Epoch 10/18
# 769500/769500 [==============================] - 162s 211us/step - loss: 8.3308 - mean_absolute_error: 8.3308 - val_loss: 20.9833 - val_mean_absolute_error: 20.9833
# Epoch 11/18
# 769500/769500 [==============================] - 162s 210us/step - loss: 8.2170 - mean_absolute_error: 8.2170 - val_loss: 22.7503 - val_mean_absolute_error: 22.7503
# Epoch 12/18
# 769500/769500 [==============================] - 162s 210us/step - loss: 8.0964 - mean_absolute_error: 8.0964 - val_loss: 20.2086 - val_mean_absolute_error: 20.2086
# Epoch 13/18
# 769500/769500 [==============================] - 162s 211us/step - loss: 7.9817 - mean_absolute_error: 7.9817 - val_loss: 19.2407 - val_mean_absolute_error: 19.2407
# Epoch 14/18
# 769500/769500 [==============================] - 162s 210us/step - loss: 7.8864 - mean_absolute_error: 7.8864 - val_loss: 19.7231 - val_mean_absolute_error: 19.7231
# Epoch 15/18
# 769500/769500 [==============================] - 163s 211us/step - loss: 7.8441 - mean_absolute_error: 7.8441 - val_loss: 20.0428 - val_mean_absolute_error: 20.0428
# Epoch 16/18
# 769500/769500 [==============================] - 162s 211us/step - loss: 7.7354 - mean_absolute_error: 7.7354 - val_loss: 21.7869 - val_mean_absolute_error: 21.7869
# Epoch 17/18
# 769500/769500 [==============================] - 163s 212us/step - loss: 7.6724 - mean_absolute_error: 7.6724 - val_loss: 20.4802 - val_mean_absolute_error: 20.4802
# Epoch 18/18
# 769500/769500 [==============================] - 162s 211us/step - loss: 7.5858 - mean_absolute_error: 7.5858 - val_loss: 19.3045 - val_mean_absolute_error: 19.3045

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()

mae_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

mae_ax.plot(hist.history['mean_absolute_error'], 'b', label='train mae')
mae_ax.plot(hist.history['val_mean_absolute_error'], 'g', label='val mae')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
mae_ax.set_ylabel('mae')

loss_ax.legend(loc='upper left')
mae_ax.legend(loc='lower left')

plt.show()

#예측값을 생성합니다.
pred_test = model.predict(x_test)
#submission 파일을 생성합니다.
sample_sub = pd.read_csv('/content/drive/My Drive/sample_submission.csv', index_col=0)
submission = sample_sub+pred_test
submission.to_csv('submission_200202_2.csv')
