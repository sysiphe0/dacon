# %% [markdown]
# <a href="https://colab.research.google.com/github/sysiphe0/dacon/blob/master/2001_semicon_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import io

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
train = pd.read_csv('/content/drive/My Drive/train.csv')

# %%
test = pd.read_csv('/content/drive/My Drive/test.csv')

# %%
train.head()
# Out:
#    layer_1  layer_2  layer_3  layer_4  ...       222       223       224       225
# 0       10       10       10       10  ...  0.419225  0.443250  0.433414  0.465502
# 1       10       10       10       20  ...  0.637706  0.625981  0.653231  0.637853
# 2       10       10       10       30  ...  0.747743  0.746037  0.737356  0.750391
# 3       10       10       10       40  ...  0.774712  0.801526  0.805305  0.784057
# 4       10       10       10       50  ...  0.787763  0.794948  0.819105  0.801781
#
# [5 rows x 230 columns]

# %%
#@title 기본 제목 텍스트
#독립변수와 종속변수를 분리합니다.
from sklearn.model_selection import train_test_split
x_train = train.iloc[:,4:]  #Train 데이터의 독립변수
y_train = train.iloc[:,0:4] #Train 데이터의 종속변수
#x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size=0.2, random_state=0)

# %%
x_test = test.iloc[:,1:]    #Test  데이터의 독립변수

# %%
#케라스를 통해 모델 생성을 시작합니다.
import keras
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.add(Dense(units=160, activation='relu', input_dim=226))
model.add(Dense(units=160, activation='relu'))
model.add(Dense(units=160, activation='relu'))
model.add(Dense(units=160, activation='relu'))
model.add(Dense(units=160, activation='relu'))
model.add(Dense(units=160, activation='relu'))
model.add(Dense(units=160, activation='relu'))
model.add(Dense(units=4, activation='linear'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
#모델을 컴파일합니다.
model.compile(loss='mae', optimizer='adam', metrics=['mae'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#모델을 학습합니다.
hist = model.fit(x_train, y_train, epochs=30, batch_size=10, validation_split = 0.05)

# %matplotlib inline
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()

mae_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

mae_ax.plot(hist.history['mean_absolute_error'], 'b', label='train mae')
mae_ax.plot(hist.history['val_mean_absolute_error'], 'g', label='val mae')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
mae_ax.set_ylabel('mae')

loss_ax.legend(loc='upper left')
mae_ax.legend(loc='lower left')

plt.show()

#예측값을 생성합니다.
pred_test = model.predict(x_test)
#submission 파일을 생성합니다.
sample_sub = pd.read_csv('/content/drive/My Drive/sample_submission.csv', index_col=0)
submission = sample_sub+pred_test
submission.to_csv('submission_200201.csv')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 769500 samples, validate on 40500 samples
# Epoch 1/30
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 769500/769500 [==============================] - 374s 486us/step - loss: 45.9820 - mean_absolute_error: 45.9820 - val_loss: 49.6062 - val_mean_absolute_error: 49.6062
# Epoch 2/30
# 769500/769500 [==============================] - 371s 482us/step - loss: 28.4029 - mean_absolute_error: 28.4029 - val_loss: 42.3101 - val_mean_absolute_error: 42.3101
# Epoch 3/30
# 769500/769500 [==============================] - 367s 477us/step - loss: 22.8291 - mean_absolute_error: 22.8291 - val_loss: 37.3581 - val_mean_absolute_error: 37.3581
# Epoch 4/30
# 769500/769500 [==============================] - 362s 470us/step - loss: 19.8231 - mean_absolute_error: 19.8231 - val_loss: 38.7956 - val_mean_absolute_error: 38.7956
# Epoch 5/30
# 769500/769500 [==============================] - 361s 469us/step - loss: 17.9561 - mean_absolute_error: 17.9561 - val_loss: 34.9230 - val_mean_absolute_error: 34.9230
# Epoch 6/30
# 769500/769500 [==============================] - 359s 467us/step - loss: 16.6371 - mean_absolute_error: 16.6371 - val_loss: 34.7564 - val_mean_absolute_error: 34.7564
# Epoch 7/30
# 769500/769500 [==============================] - 353s 459us/step - loss: 15.7036 - mean_absolute_error: 15.7036 - val_loss: 32.2967 - val_mean_absolute_error: 32.2967
# Epoch 8/30
# 769500/769500 [==============================] - 358s 465us/step - loss: 14.9780 - mean_absolute_error: 14.9780 - val_loss: 30.1782 - val_mean_absolute_error: 30.1782
# Epoch 9/30
# 769500/769500 [==============================] - 359s 467us/step - loss: 14.4510 - mean_absolute_error: 14.4510 - val_loss: 31.3633 - val_mean_absolute_error: 31.3633
# Epoch 10/30
# 769500/769500 [==============================] - 366s 476us/step - loss: 14.0504 - mean_absolute_error: 14.0504 - val_loss: 29.7379 - val_mean_absolute_error: 29.7379
# Epoch 11/30
# 769500/769500 [==============================] - 360s 468us/step - loss: 13.7118 - mean_absolute_error: 13.7118 - val_loss: 31.3543 - val_mean_absolute_error: 31.3543
# Epoch 12/30
# 769500/769500 [==============================] - 363s 472us/step - loss: 13.4141 - mean_absolute_error: 13.4141 - val_loss: 27.7848 - val_mean_absolute_error: 27.7848
# Epoch 13/30
# 769500/769500 [==============================] - 364s 474us/step - loss: 13.1581 - mean_absolute_error: 13.1581 - val_loss: 28.8047 - val_mean_absolute_error: 28.8047
# Epoch 14/30
# 769500/769500 [==============================] - 364s 473us/step - loss: 12.9321 - mean_absolute_error: 12.9321 - val_loss: 30.8271 - val_mean_absolute_error: 30.8271
# Epoch 15/30
# 769500/769500 [==============================] - 364s 473us/step - loss: 12.7424 - mean_absolute_error: 12.7424 - val_loss: 29.8509 - val_mean_absolute_error: 29.8509
# Epoch 16/30
# 769500/769500 [==============================] - 370s 481us/step - loss: 12.5469 - mean_absolute_error: 12.5469 - val_loss: 26.4985 - val_mean_absolute_error: 26.4985
# Epoch 17/30
# 769500/769500 [==============================] - 361s 469us/step - loss: 12.4338 - mean_absolute_error: 12.4338 - val_loss: 24.9081 - val_mean_absolute_error: 24.9081
# Epoch 18/30
# 769500/769500 [==============================] - 363s 471us/step - loss: 12.3064 - mean_absolute_error: 12.3064 - val_loss: 24.9784 - val_mean_absolute_error: 24.9784
# Epoch 19/30
# 769500/769500 [==============================] - 358s 465us/step - loss: 12.1658 - mean_absolute_error: 12.1658 - val_loss: 28.8703 - val_mean_absolute_error: 28.8703
# Epoch 20/30
# 769500/769500 [==============================] - 363s 472us/step - loss: 11.9994 - mean_absolute_error: 11.9994 - val_loss: 28.0445 - val_mean_absolute_error: 28.0445
# Epoch 21/30
# 769500/769500 [==============================] - 363s 471us/step - loss: 11.8493 - mean_absolute_error: 11.8493 - val_loss: 28.1694 - val_mean_absolute_error: 28.1694
# Epoch 22/30
# 769500/769500 [==============================] - 370s 481us/step - loss: 11.7207 - mean_absolute_error: 11.7207 - val_loss: 27.6238 - val_mean_absolute_error: 27.6238
# Epoch 23/30
# 769500/769500 [==============================] - 390s 507us/step - loss: 11.6682 - mean_absolute_error: 11.6682 - val_loss: 25.9996 - val_mean_absolute_error: 25.9996
# Epoch 24/30
# 769500/769500 [==============================] - 375s 487us/step - loss: 11.5509 - mean_absolute_error: 11.5509 - val_loss: 27.6387 - val_mean_absolute_error: 27.6387
# Epoch 25/30
# 769500/769500 [==============================] - 376s 489us/step - loss: 11.4353 - mean_absolute_error: 11.4353 - val_loss: 28.8472 - val_mean_absolute_error: 28.8472
# Epoch 26/30
# 769500/769500 [==============================] - 375s 488us/step - loss: 11.4081 - mean_absolute_error: 11.4081 - val_loss: 26.8105 - val_mean_absolute_error: 26.8105
# Epoch 27/30
# 769500/769500 [==============================] - 377s 490us/step - loss: 11.3553 - mean_absolute_error: 11.3553 - val_loss: 30.3269 - val_mean_absolute_error: 30.3269
# Epoch 28/30
# 769500/769500 [==============================] - 370s 481us/step - loss: 11.3036 - mean_absolute_error: 11.3036 - val_loss: 29.2559 - val_mean_absolute_error: 29.2559
# Epoch 29/30
# 769500/769500 [==============================] - 379s 492us/step - loss: 11.2340 - mean_absolute_error: 11.2340 - val_loss: 27.2586 - val_mean_absolute_error: 27.2586
# Epoch 30/30
# 769500/769500 [==============================] - 384s 499us/step - loss: 11.1835 - mean_absolute_error: 11.1835 - val_loss: 28.9324 - val_mean_absolute_error: 28.9324
