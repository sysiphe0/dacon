# %% [markdown]
# <a href="https://colab.research.google.com/github/sysiphe0/dacon/blob/master/2001_semicon_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import io

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
train = pd.read_csv('/content/drive/My Drive/train.csv')

# %%
test = pd.read_csv('/content/drive/My Drive/test.csv')

# %%
train.head()
# Out:
#    layer_1  layer_2  layer_3  layer_4  ...       222       223       224       225
# 0       10       10       10       10  ...  0.419225  0.443250  0.433414  0.465502
# 1       10       10       10       20  ...  0.637706  0.625981  0.653231  0.637853
# 2       10       10       10       30  ...  0.747743  0.746037  0.737356  0.750391
# 3       10       10       10       40  ...  0.774712  0.801526  0.805305  0.784057
# 4       10       10       10       50  ...  0.787763  0.794948  0.819105  0.801781
#
# [5 rows x 230 columns]

# %%
#@title 기본 제목 텍스트
#독립변수와 종속변수를 분리합니다.
from sklearn.model_selection import train_test_split
x_train = train.iloc[:,4:]  #Train 데이터의 독립변수
y_train = train.iloc[:,0:4] #Train 데이터의 종속변수
#x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size=0.2, random_state=0)
x_test = test.iloc[:,1:]    #Test  데이터의 독립변수

# %%
#케라스를 통해 모델 생성을 시작합니다.
import keras
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.add(Dense(units=160, activation='relu', input_dim=226))
model.add(Dense(units=160, activation='relu'))
model.add(Dense(units=160, activation='relu'))
model.add(Dense(units=160, activation='relu'))
model.add(Dense(units=160, activation='relu'))
model.add(Dense(units=160, activation='relu'))
model.add(Dense(units=160, activation='relu'))
model.add(Dense(units=4, activation='linear'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
#모델을 컴파일합니다.
model.compile(loss='mae', optimizer='adam', metrics=['mae'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#모델을 학습합니다.
hist = model.fit(x_train, y_train, epochs=30, batch_size=10, validation_split = 0.05)

# %matplotlib inline
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()

mae_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

mae_ax.plot(hist.history['mean_absolute_error'], 'b', label='train mae')
mae_ax.plot(hist.history['val_mean_absolute_error'], 'g', label='val mae')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
mae_ax.set_ylabel('mae')

loss_ax.legend(loc='upper left')
mae_ax.legend(loc='lower left')

plt.show()

#예측값을 생성합니다.
pred_test = model.predict(x_test)
#submission 파일을 생성합니다.
sample_sub = pd.read_csv('/content/drive/My Drive/sample_submission.csv', index_col=0)
submission = sample_sub+pred_test
submission.to_csv('submission_200201.csv')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 769500 samples, validate on 40500 samples
# Epoch 1/30
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 769500/769500 [==============================] - 375s 487us/step - loss: 48.0725 - mean_absolute_error: 48.0725 - val_loss: 48.9461 - val_mean_absolute_error: 48.9461
# Epoch 2/30
# 769500/769500 [==============================] - 360s 468us/step - loss: 30.4290 - mean_absolute_error: 30.4290 - val_loss: 47.0203 - val_mean_absolute_error: 47.0203
# Epoch 3/30
# 769500/769500 [==============================] - 360s 468us/step - loss: 23.9608 - mean_absolute_error: 23.9608 - val_loss: 40.6506 - val_mean_absolute_error: 40.6506
# Epoch 4/30
# 769500/769500 [==============================] - 358s 465us/step - loss: 20.6897 - mean_absolute_error: 20.6897 - val_loss: 38.2773 - val_mean_absolute_error: 38.2773
# Epoch 5/30
# 769500/769500 [==============================] - 357s 464us/step - loss: 18.7329 - mean_absolute_error: 18.7329 - val_loss: 37.3564 - val_mean_absolute_error: 37.3564
# Epoch 6/30
# 769500/769500 [==============================] - 350s 455us/step - loss: 17.4992 - mean_absolute_error: 17.4992 - val_loss: 37.0706 - val_mean_absolute_error: 37.0706
# Epoch 7/30
# 769500/769500 [==============================] - 332s 432us/step - loss: 16.6185 - mean_absolute_error: 16.6185 - val_loss: 38.7062 - val_mean_absolute_error: 38.7062
# Epoch 8/30
# 769500/769500 [==============================] - 330s 429us/step - loss: 15.8804 - mean_absolute_error: 15.8804 - val_loss: 31.0946 - val_mean_absolute_error: 31.0946
# Epoch 9/30
# 769500/769500 [==============================] - 328s 427us/step - loss: 15.3969 - mean_absolute_error: 15.3969 - val_loss: 36.5860 - val_mean_absolute_error: 36.5860
# Epoch 10/30
# 769500/769500 [==============================] - 328s 426us/step - loss: 14.9338 - mean_absolute_error: 14.9338 - val_loss: 36.0228 - val_mean_absolute_error: 36.0228
# Epoch 11/30
# 769500/769500 [==============================] - 328s 426us/step - loss: 14.5739 - mean_absolute_error: 14.5739 - val_loss: 35.3262 - val_mean_absolute_error: 35.3262
# Epoch 12/30
# 769500/769500 [==============================] - 327s 425us/step - loss: 14.2580 - mean_absolute_error: 14.2580 - val_loss: 34.3993 - val_mean_absolute_error: 34.3993
# Epoch 13/30
# 769500/769500 [==============================] - 328s 426us/step - loss: 14.0169 - mean_absolute_error: 14.0169 - val_loss: 30.5591 - val_mean_absolute_error: 30.5591
# Epoch 14/30
# 769500/769500 [==============================] - 326s 423us/step - loss: 13.8102 - mean_absolute_error: 13.8102 - val_loss: 29.7949 - val_mean_absolute_error: 29.7949
# Epoch 15/30
# 769500/769500 [==============================] - 326s 424us/step - loss: 13.6174 - mean_absolute_error: 13.6174 - val_loss: 32.3145 - val_mean_absolute_error: 32.3145
# Epoch 16/30
# 769500/769500 [==============================] - 324s 421us/step - loss: 13.4093 - mean_absolute_error: 13.4093 - val_loss: 34.7611 - val_mean_absolute_error: 34.7611
# Epoch 17/30
# 769500/769500 [==============================] - 325s 422us/step - loss: 13.2202 - mean_absolute_error: 13.2202 - val_loss: 33.0643 - val_mean_absolute_error: 33.0643
# Epoch 18/30
# 769500/769500 [==============================] - 324s 421us/step - loss: 13.0352 - mean_absolute_error: 13.0352 - val_loss: 29.8608 - val_mean_absolute_error: 29.8608
# Epoch 19/30
# 769500/769500 [==============================] - 323s 420us/step - loss: 12.8420 - mean_absolute_error: 12.8420 - val_loss: 29.2300 - val_mean_absolute_error: 29.2300
# Epoch 20/30
# 769500/769500 [==============================] - 325s 423us/step - loss: 12.7797 - mean_absolute_error: 12.7797 - val_loss: 31.0288 - val_mean_absolute_error: 31.0288
# Epoch 21/30
# 769500/769500 [==============================] - 324s 421us/step - loss: 12.6285 - mean_absolute_error: 12.6285 - val_loss: 29.1959 - val_mean_absolute_error: 29.1959
# Epoch 22/30
# 769500/769500 [==============================] - 324s 421us/step - loss: 12.5045 - mean_absolute_error: 12.5045 - val_loss: 33.5311 - val_mean_absolute_error: 33.5311
# Epoch 23/30
# 769500/769500 [==============================] - 324s 421us/step - loss: 12.4180 - mean_absolute_error: 12.4180 - val_loss: 29.8335 - val_mean_absolute_error: 29.8335
# Epoch 24/30
# 769500/769500 [==============================] - 323s 420us/step - loss: 12.3327 - mean_absolute_error: 12.3327 - val_loss: 36.2537 - val_mean_absolute_error: 36.2537
# Epoch 25/30
# 769500/769500 [==============================] - 323s 420us/step - loss: 12.1857 - mean_absolute_error: 12.1857 - val_loss: 30.1210 - val_mean_absolute_error: 30.1210
# Epoch 26/30
# 769500/769500 [==============================] - 324s 421us/step - loss: 12.2279 - mean_absolute_error: 12.2279 - val_loss: 29.1648 - val_mean_absolute_error: 29.1648
# Epoch 27/30
# 769500/769500 [==============================] - 324s 421us/step - loss: 12.0920 - mean_absolute_error: 12.0920 - val_loss: 27.4176 - val_mean_absolute_error: 27.4176
# Epoch 28/30
# 769500/769500 [==============================] - 323s 420us/step - loss: 12.0771 - mean_absolute_error: 12.0771 - val_loss: 29.5162 - val_mean_absolute_error: 29.5162
# Epoch 29/30
# 769500/769500 [==============================] - 323s 420us/step - loss: 11.9909 - mean_absolute_error: 11.9909 - val_loss: 28.7208 - val_mean_absolute_error: 28.7208
# Epoch 30/30
# 769500/769500 [==============================] - 325s 422us/step - loss: 11.9074 - mean_absolute_error: 11.9074 - val_loss: 30.0366 - val_mean_absolute_error: 30.0366
